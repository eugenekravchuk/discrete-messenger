# %% [markdown]
# Графік порівняння часу кодування

# %%
import matplotlib.pyplot as plt

# Дані для роботи алгоритмів (приклад)
data_sizes = ["Малий текст", "Середній текст", "Великий текст", "Мале фото", "Велике фото"]
DSA_times = [0.0, 0.0020055770874023438, 0.0029621124267578125, 0.001230478286743164, 0.0]  # Приклад часу роботи DSA
RSA_times = [0.0026531219482421875, 0.09156990051269531, 0.14156990051269531, 0.11755228042602539, 0.352741003036499]  # Приклад часу роботи RSA
ECCDSA_times = [0.8649799823760986, 0.8998403549194336, 0.8494484424591064, 0.9005239009857178, 0.8911404609680176]  # Приклад часу роботи ECCDSA
ElGamal_times = [0.5002198219299316, 1.5568153858184814, 40.58422350883484, 4.339330673217773, 12.718733549118042]  # Приклад часу роботи ElGamal
RCS_times = [0.00035500526428222656, 0.0035390853881835938, 0.09978699684143066, 0.0036325454711914062, 0.0]  # Приклад часу роботи RCS

# Побудова графіка
plt.figure(figsize=(10, 6))  # Розмір графіка
plt.plot(data_sizes, DSA_times, marker='o', label='DSA')  # Лінія для DSA
plt.plot(data_sizes, RSA_times, marker='o', label='RSA')  # Лінія для RSA
plt.plot(data_sizes, ECCDSA_times, marker='o', label='ECCDSA')  # Лінія для ECCDSA
plt.plot(data_sizes, ElGamal_times, marker='o', label='ElGamal')  # Лінія для ElGamal
plt.plot(data_sizes, RCS_times, marker='o', label='RCS')  # Лінія для RCS

plt.xlabel('Розмір даних')  # Підпис вісі x
plt.ylabel('Час роботи (у секундах)')  # Підпис вісі y
plt.title('Порівняння часу закодовування алгоритмів')  # Заголовок графіка
plt.legend()  # Додаємо легенду

plt.grid(True)  # Включаємо сітку
plt.xticks(rotation=45)  # Повертаємо підписи на осі x

plt.tight_layout()  # Автоматично регулюємо розмір графіка
plt.show()  # Показуємо графік

# %% [markdown]
# Детальніший розгляд алгоритмів без ElGamal

# %%
import matplotlib.pyplot as plt

# Дані для роботи алгоритмів (приклад)
data_sizes = ["Малий текст", "Середній текст", "Великий текст", "Мале фото", "Велике фото"]
DSA_times = [0.0, 0.0020055770874023438, 0.0029621124267578125, 0.001230478286743164, 0.0]  # Приклад часу роботи DSA
RSA_times = [0.0026531219482421875, 0.09156990051269531, 0.14156990051269531, 0.11755228042602539, 0.352741003036499]  # Приклад часу роботи RSA
ECCDSA_times = [0.8649799823760986, 0.8998403549194336, 0.8494484424591064, 0.9005239009857178, 0.8911404609680176]  # Приклад часу роботи ECCDSA
# ElGamal_times = [0.5002198219299316, 1.5568153858184814, 40.58422350883484, 4.339330673217773, 12.718733549118042]  # Приклад часу роботи ElGamal
RCS_times = [0.00035500526428222656, 0.0035390853881835938, 0.09978699684143066, 0.0036325454711914062, 0.0]  # Приклад часу роботи RCS

# Побудова графіка
plt.figure(figsize=(10, 6))  # Розмір графіка
plt.plot(data_sizes, DSA_times, marker='o', label='DSA')  # Лінія для DSA
plt.plot(data_sizes, RSA_times, marker='o', label='RSA')  # Лінія для RSA
plt.plot(data_sizes, ECCDSA_times, marker='o', label='ECCDSA')  # Лінія для ECCDSA
# plt.plot(data_sizes, ElGamal_times, marker='o', label='ElGamal')  # Лінія для ElGamal
plt.plot(data_sizes, RCS_times, marker='o', label='RCS')  # Лінія для RCS

plt.xlabel('Розмір даних')  # Підпис вісі x
plt.ylabel('Час роботи (у секундах)')  # Підпис вісі y
plt.title('Порівняння часу закодовування алгоритмів (детальніше)')  # Заголовок графіка
plt.legend()  # Додаємо легенду

plt.grid(True)  # Включаємо сітку
plt.xticks(rotation=45)  # Повертаємо підписи на осі x

plt.tight_layout()  # Автоматично регулюємо розмір графіка
plt.show()  # Показуємо графік

# %% [markdown]
# Порівняння ефективності розкодування алгоритмів

# %%
import matplotlib.pyplot as plt

# Дані для роботи алгоритмів (приклад)
data_sizes = ["Малий текст", "Середній текст", "Великий текст", "Мале фото", "Велике фото"]
DSA_times = [0.0034933090209960938, 0.002523183822631836, 0.002604365348815918, 0.0, 0.007195234298706055]  # Приклад часу роботи DSA
RSA_times = [6.306966781616211, 219.26957297325134, 219.26957297325134, 2.110386371612549, 6.321465015411377]  # Приклад часу роботи RSA
ECCDSA_times = [2.580408215522766, 2.6326366662979126, 2.5748157501220703, 2.6983996629714966, 2.6840375661849976]  # Приклад часу роботи ECCDSA
ElGamal_times = [0.04553699493408203, 1.3722612857818604, 36.977336168289185, 3.716301202774048, 11.476421117782593]  # Приклад часу роботи ElGamal
RCS_times = [0.30039000511169434, 9.029640913009644, 249.3862841129303, 22.216952800750732, 54.513474464416504]  # Приклад часу роботи RCS

# Побудова графіка
plt.figure(figsize=(10, 6))  # Розмір графіка
plt.plot(data_sizes, DSA_times, marker='o', label='DSA')  # Лінія для DSA
plt.plot(data_sizes, RSA_times, marker='o', label='RSA')  # Лінія для RSA
plt.plot(data_sizes, ECCDSA_times, marker='o', label='ECCDSA')  # Лінія для ECCDSA
plt.plot(data_sizes, ElGamal_times, marker='o', label='ElGamal')  # Лінія для ElGamal
plt.plot(data_sizes, RCS_times, marker='o', label='RCS')  # Лінія для RCS

plt.xlabel('Розмір даних')  # Підпис вісі x
plt.ylabel('Час роботи (у секундах)')  # Підпис вісі y
plt.title('Порівняння часу розкодування алгоритмів')  # Заголовок графіка
plt.legend()  # Додаємо легенду

plt.grid(True)  # Включаємо сітку
plt.xticks(rotation=45)  # Повертаємо підписи на осі x

plt.tight_layout()  # Автоматично регулюємо розмір графіка
plt.show()  # Показуємо графік

# %% [markdown]
# Детальніший огляд

# %%
import matplotlib.pyplot as plt

# Дані для роботи алгоритмів (приклад)
data_sizes = ["Малий текст", "Середній текст", "Великий текст", "Мале фото", "Велике фото"]
DSA_times = [0.0034933090209960938, 0.002523183822631836, 0.002604365348815918, 0.0, 0.007195234298706055]  # Приклад часу роботи DSA
# RSA_times = [6.306966781616211, 219.26957297325134, 219.26957297325134, 2.110386371612549, 6.321465015411377]  # Приклад часу роботи RSA
ECCDSA_times = [2.580408215522766, 2.6326366662979126, 2.5748157501220703, 2.6983996629714966, 2.6840375661849976]  # Приклад часу роботи ECCDSA
ElGamal_times = [0.04553699493408203, 1.3722612857818604, 36.977336168289185, 3.716301202774048, 11.476421117782593]  # Приклад часу роботи ElGamal
# RCS_times = [0.30039000511169434, 9.029640913009644, 249.3862841129303, 22.216952800750732, 54.513474464416504]  # Приклад часу роботи RCS

# Побудова графіка
plt.figure(figsize=(10, 6))  # Розмір графіка
plt.plot(data_sizes, DSA_times, marker='o', label='DSA')  # Лінія для DSA
# plt.plot(data_sizes, RSA_times, marker='o', label='RSA')  # Лінія для RSA
plt.plot(data_sizes, ECCDSA_times, marker='o', label='ECCDSA')  # Лінія для ECCDSA
plt.plot(data_sizes, ElGamal_times, marker='o', label='ElGamal')  # Лінія для ElGamal
# plt.plot(data_sizes, RCS_times, marker='o', label='RCS')  # Лінія для RCS

plt.xlabel('Розмір даних')  # Підпис вісі x
plt.ylabel('Час роботи (у секундах)')  # Підпис вісі y
plt.title('Порівняння часу розкодування алгоритмів (детальніше)')  # Заголовок графіка
plt.legend()  # Додаємо легенду

plt.grid(True)  # Включаємо сітку
plt.xticks(rotation=45)  # Повертаємо підписи на осі x

plt.tight_layout()  # Автоматично регулюємо розмір графіка
plt.show()  # Показуємо графік

# %% [markdown]
# Порівняння затрат пам'яті алгоритмів

# %%
import matplotlib.pyplot as plt

# Дані для роботи алгоритмів (приклад)
data_sizes = ["Малий текст", "Середній текст", "Великий текст", "Мале фото", "Велике фото"]
DSA_times = [0.0, 0.0020055770874023438, 0.0029621124267578125, 0.001230478286743164, 0.0]  # Приклад часу роботи DSA
RSA_times = [0.004536628723144531, 0.03570556640625, 0.03570556640625, 0.04821014404296875, 0.14486312866210938]  # Приклад часу роботи RSA
ECCDSA_times = [0.16614818572998047, 0.1156320571899414, 3.303110122680664, 0.2805509567260742, 0.5860795974731445]  # Приклад часу роботи ECCDSA
ElGamal_times = [0.007800102233886719, 0.04699516296386719, 1.2032785415649414, 0.1809101104736328, 0.35483551025390625]  # Приклад часу роботи ElGamal
RCS_times = [0.05941486358642578, 0.08121204376220703, 2.188875198364258, 0.22537994384765625, 0.5062580108642578]  # Приклад часу роботи RCS

# Побудова графіка
plt.figure(figsize=(10, 6))  # Розмір графіка
plt.plot(data_sizes, DSA_times, marker='o', label='DSA')  # Лінія для DSA
plt.plot(data_sizes, RSA_times, marker='o', label='RSA')  # Лінія для RSA
plt.plot(data_sizes, ECCDSA_times, marker='o', label='ECCDSA')  # Лінія для ECCDSA
plt.plot(data_sizes, ElGamal_times, marker='o', label='ElGamal')  # Лінія для ElGamal
plt.plot(data_sizes, RCS_times, marker='o', label='RCS')  # Лінія для RCS

plt.xlabel('Розмір даних')  # Підпис вісі x
plt.ylabel("Затрати пам'яті (MB)")  # Підпис вісі y
plt.title("Порівняння затрат пам'яті алгоритмів")  # Заголовок графіка
plt.legend()  # Додаємо легенду

plt.grid(True)  # Включаємо сітку
plt.xticks(rotation=45)  # Повертаємо підписи на осі x

plt.tight_layout()  # Автоматично регулюємо розмір графіка
plt.show()  # Показуємо графік

# %% [markdown]
# Порівняння затрат часу на генерацію ключів

# %%
import matplotlib.pyplot as plt

# Дані для роботи алгоритмів (приклад)
algorithms = ["DSA", "RSA", "ECCDSA", "ElGamal", "RCS"]
key_generation_times = [28.876594066619873, 0.020760059356689453, 0.8300788402557373, 0.6861498355865479, 6.0887041091918945]  # Приклад часу генерації ключів для кожного алгоритму

# Побудова стовпчастої діаграми
plt.figure(figsize=(8, 6))  # Розмір діаграми
plt.bar(algorithms, key_generation_times, color='skyblue')  # Стовпчики діаграми

plt.xlabel('Алгоритми')  # Підпис вісі x
plt.ylabel('Час генерації ключів (у секундах)')  # Підпис вісі y
plt.title('Час генерації ключів для різних алгоритмів')  # Заголовок діаграми

plt.grid(axis='y')  # Включаємо сітку на вісі y

plt.tight_layout()  # Автоматично регулюємо розмір діаграми
plt.show()  # Показуємо діаграму

# %% [markdown]
# Порівняння затрат пам'яті на генерацію ключів

# %%
import matplotlib.pyplot as plt

# Дані для роботи алгоритмів (приклад)
algorithms = ["DSA", "RSA", "ECCDSA", "ElGamal", "RCS"]
key_generation_times = [0.012774467468261719, 0.014279365539550781, 3.3558034896850586, 4.993078231811523, 3.351292610168457]  # Приклад часу генерації ключів для кожного алгоритму

# Побудова стовпчастої діаграми
plt.figure(figsize=(8, 6))  # Розмір діаграми
plt.bar(algorithms, key_generation_times, color='skyblue')  # Стовпчики діаграми

plt.xlabel('Алгоритми')  # Підпис вісі x
plt.ylabel("Затрати пам'яті генерації ключів (MB)")  # Підпис вісі y
plt.title("Витрати пам'яті генерації ключів для різних алгоритмів")  # Заголовок діаграми

plt.grid(axis='y')  # Включаємо сітку на вісі y

plt.tight_layout()  # Автоматично регулюємо розмір діаграми
plt.show()  # Показуємо діаграму
